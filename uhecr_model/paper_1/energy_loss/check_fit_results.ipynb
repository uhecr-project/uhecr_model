# %%
import numpy as np
from matplotlib import pyplot as plt
import h5py

import sys
sys.path.append("../../../../fancy/")

from fancy.analysis.results import Results

# %%
results_file_name = "output/outputs_joint/joint_fit_SBG23_TA2015_None_N_19990308_Lloss_tightB.h5"

# %%
results = Results(results_file_name)

# %%
chain = results.get_chain(["Q", "alpha", "F0", "B", "lp", "f"]);

# %%
fig, ax = plt.subplots()
ax.hist(chain["f"]);

# %%
from scipy.special import logsumexp

# %%
np.shape(chain["lp"])
# Out:
# (4000, 72, 24)

# %%
log_prob_tmp = chain["lp"].transpose(1, 2, 0)

log_prob = 0
for lp in log_prob_tmp:
    log_prob += logsumexp(lp, axis=0)

# %%
fig, ax = plt.subplots()
ax.hist(log_prob);
